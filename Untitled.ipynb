# %%
from easyocr import Reader
import argparse
import cv2
import numpy as np

# %%
reader = Reader(['en'])
image = cv2.imread('invoice-sample.jpg')

result = []
result.append(reader.readtext('invoice-sample.jpg', paragraph='true'))
# Out:
# CUDA not available - defaulting to CPU. Note: This module is much faster with a GPU.

# %%
print(result)
# Out:
# [[[[[652, 38], [779, 38], [779, 56], [652, 56]], 'http:/ {mrsinvoice.com'], [[[57, 71], [549, 71], [549, 203], [57, 203]], 'Invoice Your Company LLC Address 123_ State_ My Country 111-222-333,F 111-222-334'], [[[57, 313], [249, 313], [249, 405], [57, 405]], 'BILL TO: Jonn Doe Alpha Bravo Road 33 P: 111-222-333, F: 111-222-334 client@example net'], [[[425, 325], [483, 325], [483, 339], [425, 339]], 'Invoice #'], [[[649, 325], [689, 325], [689, 339], [649, 339]], 'O0001'], [[[415, 353], [491, 353], [491, 369], [415, 369]], 'Invoice Date'], [[[631, 351], [705, 351], [705, 369], [631, 369]], '12/12/2001'], [[[411, 381], [491, 381], [491, 397], [411, 397]], 'Name of Rep'], [[[657, 383], [683, 383], [683, 397], [657, 397]], 'Bob'], [[[407, 409], [499, 409], [499, 425], [407, 425]], 'Contact Phone'], [[[629, 409], [709, 409], [709, 425], [629, 425]], '101-102-103'], [[[57, 429], [249, 429], [249, 521], [57, 521]], 'SHIPPING TO: John Doe Office Office Road 38 P: 111-333-222, F: 122-222-334 office@example net'], [[[405, 439], [501, 439], [501, 455], [405, 455]], 'Payment Terms'], [[[619, 437], [721, 437], [721, 455], [619, 455]], 'Cash on Delivery'], [[[468, 478], [654, 478], [654, 504], [468, 504]], 'Amount Due: $4,170'], [[[69, 621], [233, 621], [233, 637], [69, 637]], 'NO PRODUCTS SERVICE'], [[[483, 621], [557, 621], [557, 655], [483, 655]], 'QUANTITY / HOURS'], [[[575, 623], [651, 623], [651, 677], [575, 677]], 'RATE UNIT PRICE S20'], [[[707, 621], [767, 621], [767, 637], [707, 637]], 'AMOUNT'], [[[103, 663], [133, 663], [133, 677], [103, 677]], 'Tyre'], [[[739, 659], [767, 659], [767, 677], [739, 677]], 'S40'], [[[103, 689], [195, 689], [195, 755], [103, 755]], 'Steering Wheel Engine Oil Brake Pad'], [[[623, 685], [651, 685], [651, 729], [623, 729]], 'S10 S15'], [[[719, 687], [767, 687], [767, 755], [719, 755]], 'S50 S150 S2,400'], [[[611, 739], [651, 739], [651, 755], [611, 755]], 'S1000'], [[[597, 767], [647, 767], [647, 781], [597, 781]], 'Subtota'], [[[721, 767], [767, 767], [767, 835], [721, 835]], '5275 S27.5 S302.5'], [[[577, 791], [651, 791], [651, 835], [577, 835]], 'Tax (10%) Grand Total'], [[[315, 1071], [523, 1071], [523, 1089], [315, 1089]], 'THANK YOU FOR YOUR BUSINESS']]]

# %% [markdown]
# <h3 style='color:gray'>Preprocessing </h3>
# <br/>

# %%
# get grayscale image
def get_grayscale(image):
    return cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# noise removal
def remove_noise(image):
    return cv2.medianBlur(image,5)
 
#thresholding
def thresholding(image):
    return cv2.threshold(image, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)[1]

#dilation
def dilate(image):
    kernel = np.ones((5,5),np.uint8)
    return cv2.dilate(image, kernel, iterations = 1)
    
#erosion
def erode(image):
    kernel = np.ones((5,5),np.uint8)
    return cv2.erode(image, kernel, iterations = 1)

#opening - erosion followed by dilation
def opening(image):
    kernel = np.ones((5,5),np.uint8)
    return cv2.morphologyEx(image, cv2.MORPH_OPEN, kernel)

#canny edge detection
def canny(image):
    return cv2.Canny(image, 100, 200)

#skew correction
def deskew(image):
    coords = np.column_stack(np.where(image > 0))
    angle = cv2.minAreaRect(coords)[-1]
    if angle < -45:
        angle = -(90 + angle)
    else:
        angle = -angle
    (h, w) = image.shape[:2]
    center = (w // 2, h // 2)
    M = cv2.getRotationMatrix2D(center, angle, 1.0)
    rotated = cv2.warpAffine(image, M, (w, h), flags=cv2.INTER_CUBIC, borderMode=cv2.BORDER_REPLICATE)
    return rotated

# %%
gray = get_grayscale(image)
thresh = thresholding(gray)
opening = opening(gray)
canny = canny(gray)

# %%
result.append(reader.readtext(thresh))
result.append(reader.readtext(opening))
result.append(reader.readtext(canny))

# %%
resultmax=[]
for r in result: 
    for r1 in r:
        r1[1]r1[2])
# Out:
# http:/ {mrsinvoice.com
#  confidence :  0.6191263480172272
# Invoice
#  confidence :  0.8417029914472208
# Your Company LLC Address 123_
#  confidence :  0.9699016629589228
# State_
#  confidence :  0.9993438719407953
# My Country
#  confidence :  0.7690886052828926
# 111-222-333,F 111-222-334
#  confidence :  0.8944311753337679
# BILL TO:
#  confidence :  0.6356406546240435
# Invoice #
#  confidence :  0.811387206387055
# O0001
#  confidence :  0.26906153742125555
# Jonn Doe
#  confidence :  0.6923027453876681
# Alpha Bravo Road 33
#  confidence :  0.9995074579613783
# Invoice Date
#  confidence :  0.9849786514553461
# 12/12/2001
#  confidence :  0.9999289768449527
# P: 111-222-333,
#  confidence :  0.6397503523294078
# F: 111-222-334
#  confidence :  0.5610792224035954
# Name of Rep
#  confidence :  0.7325150235568189
# Bob
#  confidence :  0.9734600232950599
# client@example net
#  confidence :  0.8549727458882078
# Contact Phone
#  confidence :  0.8005528273143847
# 101-102-103
#  confidence :  0.7248737651044478
# SHIPPING TO:
#  confidence :  0.9216754797739767
# Payment Terms
#  confidence :  0.6721847037951721
# Cash on Delivery
#  confidence :  0.9991416305076098
# John Doe Office
#  confidence :  0.9536924488928928
# Office Road 38
#  confidence :  0.9979667855394677
# P: 111-333-222,
#  confidence :  0.9423392032966832
# F: 122-222-334
#  confidence :  0.4461899337005891
# Amount Due: $4,170
#  confidence :  0.930678772005757
# office@example net
#  confidence :  0.6481971928392032
# NO
#  confidence :  0.9837052332154774
# PRODUCTS
#  confidence :  0.9964580340402254
# SERVICE
#  confidence :  0.9998121521858273
# QUANTITY /
#  confidence :  0.9998358037155248
# RATE
#  confidence :  0.9999818801879883
# UNIT
#  confidence :  0.9948693513870239
# AMOUNT
#  confidence :  0.9998714686264422
# HOURS
#  confidence :  0.9997144027214881
# PRICE
#  confidence :  0.999951912425999
# Tyre
#  confidence :  0.8417240745427058
# S20
#  confidence :  0.7152124115157193
# S40
#  confidence :  0.9187766125806976
# Steering Wheel
#  confidence :  0.9998597436142949
# S10
#  confidence :  0.7570267887967882
# S50
#  confidence :  0.7772742599311007
# Engine Oil
#  confidence :  0.9541966269985762
# S15
#  confidence :  0.9703179139519146
# S150
#  confidence :  0.9872907400131226
# Brake Pad
#  confidence :  0.9999531416338481
# S1000
#  confidence :  0.5186406131030744
# S2,400
#  confidence :  0.8775071761664961
# Subtota
#  confidence :  0.9998919517258852
# 5275
#  confidence :  0.6954988837242126
# Tax (10%)
#  confidence :  0.9107767277024413
# S27.5
#  confidence :  0.6266061530813338
# Grand Total
#  confidence :  0.9900361878535622
# S302.5
#  confidence :  0.7306893740463919
# THANK YOU FOR YOUR BUSINESS
#  confidence :  0.9933051128405889
# http:/ {mrsinvoice.com
#  confidence :  0.6191263480172272
# Invoice
#  confidence :  0.8417029914472208
# Your Company LLC Address 123_
#  confidence :  0.9699016629589228
# State_
#  confidence :  0.9993438719407953
# My Country
#  confidence :  0.7690886052828926
# 111-222-333,F 111-222-334
#  confidence :  0.8944311753337679
# BILL TO:
#  confidence :  0.6356406546240435
# Invoice #
#  confidence :  0.811387206387055
# O0001
#  confidence :  0.26906153742125555
# Jonn Doe
#  confidence :  0.6923027453876681
# Alpha Bravo Road 33
#  confidence :  0.9995074579613783
# Invoice Date
#  confidence :  0.9849786514553461
# 12/12/2001
#  confidence :  0.9999289768449527
# P: 111-222-333,
#  confidence :  0.6397503523294078
# F: 111-222-334
#  confidence :  0.5610792224035954
# Name of Rep
#  confidence :  0.7325150235568189
# Bob
#  confidence :  0.9734600232950599
# client@example net
#  confidence :  0.8549727458882078
# Contact Phone
#  confidence :  0.8005528273143847
# 101-102-103
#  confidence :  0.7248737651044478
# SHIPPING TO:
#  confidence :  0.9216754797739767
# Payment Terms
#  confidence :  0.6721847037951721
# Cash on Delivery
#  confidence :  0.9991416305076098
# John Doe Office
#  confidence :  0.9536924488928928
# Office Road 38
#  confidence :  0.9979667855394677
# P: 111-333-222,
#  confidence :  0.9423392032966832
# F: 122-222-334
#  confidence :  0.4461899337005891
# Amount Due: $4,170
#  confidence :  0.930678772005757
# office@example net
#  confidence :  0.6481971928392032
# NO
#  confidence :  0.9837052332154774
# PRODUCTS
#  confidence :  0.9964580340402254
# SERVICE
#  confidence :  0.9998121521858273
# QUANTITY /
#  confidence :  0.9998358037155248
# RATE
#  confidence :  0.9999818801879883
# UNIT
#  confidence :  0.9948693513870239
# AMOUNT
#  confidence :  0.9998714686264422
# HOURS
#  confidence :  0.9997144027214881
# PRICE
#  confidence :  0.999951912425999
# Tyre
#  confidence :  0.9837095437886926
# S20
#  confidence :  0.7334663535766752
# S40
#  confidence :  0.9207816233953957
# Steering Wheel
#  confidence :  0.9998597436142949
# S10
#  confidence :  0.7570267887967882
# S50
#  confidence :  0.7772742599311007
# Engine Oil
#  confidence :  0.9381198268403879
# S15
#  confidence :  0.965239862073674
# S150
#  confidence :  0.9856511950492859
# Brake Pad
#  confidence :  0.9999531416338481
# S1000
#  confidence :  0.5186406131030744
# S2,400
#  confidence :  0.8066187449842525
# Subtota
#  confidence :  0.9999175898768282
# 5275
#  confidence :  0.7278725504875183
# Tax (10%)
#  confidence :  0.6282633049296196
# S27.5
#  confidence :  0.6164487963233493
# Grand Total
#  confidence :  0.988138542116704
# S302.5
#  confidence :  0.7469014903210015
# THANK YOU FOR YOUR BUSINESS
#  confidence :  0.9933051128405889
# http:f {rrsinvoice:
#  confidence :  0.7141858357092209
# LcdM
#  confidence :  0.0031136965844780207
# Invoice
#  confidence :  0.9998376107604902
# Your Company LLC Address 123, State_
#  confidence :  0.9474779379503822
# My Country
#  confidence :  0.966375955752297
# 111-222-333,
#  confidence :  0.8380960219837074
# 111-222-334
#  confidence :  0.9174791864574171
# BILE TO:
#  confidence :  0.8139710552890725
# Invoice #
#  confidence :  0.6854688700451639
# D0001
#  confidence :  0.08130998126214466
# John Doe
#  confidence :  0.8099842966511056
# Alpha Bravo Road 33
#  confidence :  0.9295965863786775
# Invoice Date
#  confidence :  0.998972780971024
# 12/12/2001
#  confidence :  0.6690928799978615
# P: 111-222-3335
#  confidence :  0.705058343245267
# F: 111-222-334
#  confidence :  0.6286528541589724
# Name of Rep
#  confidence :  0.8431641065780385
# Bob
#  confidence :  0.9998199546233127
# client@example net
#  confidence :  0.8954051414104259
# Contact Phone
#  confidence :  0.9976784345295383
# 101-102-103
#  confidence :  0.6525209550852012
# SHIPPING TO:
#  confidence :  0.9276116454554089
# Payment Terms
#  confidence :  0.6970416435869033
# Cash on Delivery
#  confidence :  0.9930486097624104
# John Doe Office
#  confidence :  0.9821985713208683
# Office Road 38
#  confidence :  0.9396597462530426
# P: 111-333-222, F; 122-222-334
#  confidence :  0.38283805082849853
# Amount Due: $4,170
#  confidence :  0.752205507386078
# office@example net
#  confidence :  0.6946062655051297
# NO
#  confidence :  0.9479961008980922
# PRODUCTS
#  confidence :  0.9964833318465578
# SERVICE
#  confidence :  0.9996834592670633
# QUANTITY _
#  confidence :  0.9742843924605391
# RATE
#  confidence :  0.9999287128448486
# UNIT
#  confidence :  0.999270498752594
# AMOUNT
#  confidence :  0.9626132322418969
# HQURS
#  confidence :  0.8063569404919183
# PRICE
#  confidence :  0.8998274243465394
# Tyre
#  confidence :  0.9229812622070312
# S20
#  confidence :  0.6150883749299025
# $40
#  confidence :  0.38227367237447435
# Steering Wheef
#  confidence :  0.9522026044329661
# S10
#  confidence :  0.920548219831465
# S5o
#  confidence :  0.6378963750213262
# Engine Oil
#  confidence :  0.9884937613775023
# S15
#  confidence :  0.9166206891072283
# S150
#  confidence :  0.7789878627855165
# Brake Pad
#  confidence :  0.9985975793771983
# S10Co
#  confidence :  0.23378570654517672
# S2,400
#  confidence :  0.6622517706500429
# Subtotal
#  confidence :  0.9997042795981984
# S275
#  confidence :  0.6093161106109619
# Tax (10%6)
#  confidence :  0.39123981395199486
# S27,5
#  confidence :  0.7704132045663561
# Grand Total
#  confidence :  0.9999320331126668
# S302,5
#  confidence :  0.6281721049406863
# THANK YOU FOR YOUR BUSINESS
#  confidence :  0.7112887211165085

# %%
print(result)
# Out:
# [[([[652, 38], [779, 38], [779, 56], [652, 56]], 'http:/ {mrsinvoice.com', 0.6191263480172272), ([[115, 71], [501, 71], [501, 183], [115, 183]], 'Invoice', 0.8417029914472208), ([[57, 187], [251, 187], [251, 203], [57, 203]], 'Your Company LLC Address 123_', 0.9699016629589228), ([[255, 189], [289, 189], [289, 203], [255, 203]], 'State_', 0.9993438719407953), ([[293, 187], [367, 187], [367, 203], [293, 203]], 'My Country', 0.7690886052828926), ([[377, 187], [549, 187], [549, 203], [377, 203]], '111-222-333,F 111-222-334', 0.8944311753337679), ([[59, 313], [111, 313], [111, 327], [59, 327]], 'BILL TO:', 0.6356406546240435), ([[425, 325], [483, 325], [483, 339], [425, 339]], 'Invoice #', 0.811387206387055), ([[649, 325], [689, 325], [689, 339], [649, 339]], 'O0001', 0.26906153742125555), ([[57, 333], [117, 333], [117, 347], [57, 347]], 'Jonn